# %%
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv

load_dotenv()
from langchain.chat_models import init_chat_model

api_key= os.getenv("GROQ_API_KEY")

llm = ChatGroq(model = "llama-3.1-8b-instant", api_key = api_key)

# %%
response = llm.invoke("whats 2 + 2")
response.content
# Out:
# '2 + 2 = 4'

# %%
input_text = input("Enter Human Message (/exit to quit): \n\n") 
while(input_text != "/exit"): 
    response = llm.invoke(input_text) 
    print("AI: " + response.content + "\n\n") 
    input_text = input("Enter Human Message (/exit to quit): \n\n") 
print("Exiting...")
# Out:
# Enter Human Message (/exit to quit):
#
#  Recipe to make Butter Chicken
# AI: Butter Chicken, also known as Murgh Makhani, is a popular Indian dish that originated in the city of Delhi. It's a creamy, rich, and flavorful dish made with marinated chicken cooked in a buttery tomato sauce. Here's a simple recipe to make Butter Chicken at home:
#
# **Ingredients:**
#
# For the marinade:
#
# - 1 1/2 pounds boneless, skinless chicken breast or thighs, cut into bite-sized pieces
# - 1/2 cup plain yogurt
# - 2 tablespoons lemon juice
# - 2 tablespoons ghee or vegetable oil
# - 2 teaspoons garam masala powder
# - 1 teaspoon cumin powder
# - 1 teaspoon coriander powder
# - 1/2 teaspoon cayenne pepper (optional)
# - Salt, to taste
#
# For the sauce:
#
# - 2 tablespoons butter
# - 2 tablespoons ghee or vegetable oil
# - 2 onions, thinly sliced
# - 2 cloves garlic, minced
# - 2 medium tomatoes, diced
# - 2 tablespoons tomato puree
# - 2 tablespoons heavy cream
# - 1 tablespoon garam masala powder
# - 1 teaspoon cumin powder
# - 1 teaspoon coriander powder
# - Salt, to taste
# - Fresh cilantro, for garnish
#
# **Instructions:**
#
# 1. **Marinate the chicken:** In a large bowl, whisk together the yogurt, lemon juice, ghee or oil, garam masala powder, cumin powder, coriander powder, cayenne pepper (if using), and salt. Add the chicken pieces and mix well to coat. Cover the bowl with plastic wrap and refrigerate for at least 30 minutes or up to 2 hours.
# 2. **Make the sauce:** In a large saucepan, melt the butter over medium heat. Add the ghee or oil and swirl it around. Add the sliced onions and cook, stirring occasionally, until they are lightly browned and caramelized, about 8-10 minutes.
# 3. **Add the garlic and ginger:** Add the minced garlic and cook for 1 minute, stirring constantly to prevent burning.
# 4. **Add the tomatoes and spices:** Add the diced tomatoes, tomato puree, garam masala powder, cumin powder, coriander powder, and salt. Cook, stirring occasionally, for 5-7 minutes or until the sauce thickens slightly.
# 5. **Add the heavy cream:** Stir in the heavy cream and cook for 2-3 minutes or until the sauce thickens to your liking. Season with salt to taste.
# 6. **Cook the chicken:** Remove the chicken from the marinade, allowing any excess to drip off. Add the chicken to the saucepan and cook, stirring occasionally, until the chicken is cooked through and the sauce has thickened, about 5-7 minutes.
# 7. **Finish with butter:** Stir in the melted butter and cook for 1-2 minutes or until the sauce is smooth and creamy.
# 8. **Serve:** Serve the Butter Chicken hot, garnished with fresh cilantro and accompanied by basmati rice or naan bread.
#
# **Tips and Variations:**
#
# - Use high-quality spices and fresh ingredients for the best flavor.
# - Adjust the level of spiciness to your taste by adding more or less cayenne pepper.
# - Add some acidity to the sauce by stirring in a tablespoon or two of lemon juice.
# - For a creamier sauce, add more heavy cream or substitute with half-and-half or coconut cream.
# - Experiment with different types of protein, such as shrimp or lamb, for a unique twist on the dish.
#
# I hope you enjoy this recipe for Butter Chicken!
# Enter Human Message (/exit to quit):
#
#  What is Langchain
# AI: LangChain is an open-source, extensible, and modular framework for building conversational AI applications. It was created by the LangChain Labs team, which includes a group of researchers and engineers from companies like Meta AI, Google, and Stanford University.
#
# LangChain is designed to make it easier for developers to build conversational AI models, such as chatbots, virtual assistants, and other language-based applications. It provides a set of pre-built components and tools that can be used to create, train, and deploy conversational AI models.
#
# The LangChain framework includes several key features, such as:
#
# 1. **Modular architecture**: LangChain's architecture is designed to be modular, allowing developers to easily swap out or add new components as needed.
# 2. **Extensive toolkit**: LangChain provides a wide range of pre-built components and tools for tasks such as natural language processing (NLP), dialogue management, and machine learning.
# 3. **Support for multiple frameworks**: LangChain can be used with a variety of frameworks, including TensorFlow, PyTorch, and Hugging Face Transformers.
# 4. **Open-source and community-driven**: LangChain is open-source, which means that developers can contribute to its development and use it freely.
#
# Some of the key use cases for LangChain include:
#
# 1. **Chatbots and virtual assistants**: LangChain can be used to build conversational AI models that can engage with users in a natural and intuitive way.
# 2. **Language translation**: LangChain's NLP capabilities can be used to translate text between languages.
# 3. **Content generation**: LangChain's machine learning capabilities can be used to generate content, such as text or speech, based on a given prompt.
# 4. **Dialogue systems**: LangChain can be used to build dialogue systems that can engage in conversation with users.
#
# Overall, LangChain is a powerful tool for building conversational AI applications, and its open-source and community-driven nature makes it an attractive option for developers and researchers.

# %%
test = input("rtnlo")
