# %% [markdown]
# Now we know what is LLM, How to call LLM, Agents, State, Memory, Graph.
#
# We are stepping up our game, So should our code.

# %% [markdown]
# We were calling this block in each of our notebook in Basics 👇🏻

# %%
from langchain_groq import ChatGroq
import os
from dotenv import load_dotenv

load_dotenv()
from langchain.chat_models import init_chat_model

api_key= os.getenv("GROQ_API_KEY")

llm = ChatGroq(model = "llama-3.1-8b-instant", api_key = api_key)

# %% [markdown]
# Why do we need to write same thing again and again? We will store it in a file and reuse it now onwards!

# %% [markdown]
# Not only this but everything which we may need to use again, will be a shared block. Try to reduce hardcoding as well, it will make our life simple

# %% [markdown]
# In Intermediate we will be learning about different Workflows and agents, MCP, RAG, and further Langchain Ecosystem Capabilities
